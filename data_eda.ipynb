# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("glassdoor_jobs_data_cleaned.csv")

# %%
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  employer_provided  min_salary  \
# count  742.000000   742.000000  742.000000         742.000000  742.000000
# mean     3.618868  1837.154987    0.032345           0.022911   74.587601
# std      0.801210   497.183763    0.177034           0.149721   31.129303
# min     -1.000000    -1.000000    0.000000           0.000000   15.000000
# 25%      3.300000  1939.000000    0.000000           0.000000   52.000000
# 50%      3.700000  1988.000000    0.000000           0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000           0.000000   91.000000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        max_salary  avg_salary  hq_same_state  age_of_company   python_yn  \
# count  742.000000  742.000000     742.000000      742.000000  742.000000
# mean   127.950135  100.626011       0.557951       46.591644    0.528302
# std     45.522179   38.855948       0.496965       53.778815    0.499535
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_name_txt', 'job_state', 'hq_same_state', 'age_of_company',
#        'python_yn', 'r_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'job_simp',
#        'seniority', 'job_desc_len', 'comp_count'],
#       dtype='object')

# %%
df.Rating.hist()
#Close to normal distribution

# %%
df.avg_salary.hist()

# %%
df.age_of_company.hist()
#exponential distribution
#needs to be normalised

# %%
df.job_desc_len.hist()
#pretty close to normal distribution

# %%
df.boxplot(column = ['Rating','age_of_company', 'avg_salary', 'job_desc_len'])

# %%
#Since the job_desc_len has larger values it can't be plotted along with the other 3 columns
df.boxplot(column = ['Rating','age_of_company', 'avg_salary'])
#It is clear that there are larget outlier for age_of_company and avg_salary

# %%
df.boxplot(column = ['Rating'])
#Fewer outliers, however there are values with -1, which have to be replaced or exlcuded(no rating)

# %%
df[['Rating','age_of_company', 'avg_salary', 'job_desc_len','comp_count']].corr()
#Older companies have longer job description
# Out:
#                   Rating  age_of_company  avg_salary  job_desc_len  comp_count
# Rating          1.000000        0.021655    0.013492     -0.012281    0.027190
# age_of_company  0.021655        1.000000    0.019655      0.163911    0.126687
# avg_salary      0.013492        0.019655    1.000000      0.078808    0.093813
# job_desc_len   -0.012281        0.163911    0.078808      1.000000    0.104620
# comp_count      0.027190        0.126687    0.093813      0.104620    1.000000

# %%
cmap = sns.diverging_palette(220,10,as_cmap = True)
sns.heatmap(df[['Rating','age_of_company', 'avg_salary', 'job_desc_len','comp_count']].corr(), vmax=.3, center=0, cmap=cmap,
           square= True, linewidths=.5, cbar_kws={"shrink": .5})

#Older companies have larger dedscription length
#Older companies have more competitiors and companies with more competitiors has larger description
#Age and avg_salary has next strongest correlation
#Rating is not correlated with any of the other columns but slightly negatively correlated with job_desc_len

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_name_txt', 'job_state', 'hq_same_state', 'age_of_company',
#        'python_yn', 'r_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'job_simp',
#        'seniority', 'job_desc_len', 'comp_count'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue','company_name_txt', 'job_state', 'hq_same_state','python_yn', 'r_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'job_simp',
       'seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    sns.barplot(x = cat_num.index, y = cat_num)
    plt.show()

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" %(i,len(cat_num)))
    chart = sns.barplot(x = cat_num.index, y = cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation = 90) #for totating labels
    plt.show()
    
#There are more companies with 1000 to 5000 employees
#Private companies are most common
#Interesting to see that Data Scienc field is big in Biotech & Pharma
#Biggest companies hire more data scientists interms of revenue
# Out:
# graph for Location: total = 200
# graph for Headquarters: total = 198
# graph for Size: total = 9
# graph for Type of ownership: total = 11
# graph for Industry: total = 60
# graph for Sector: total = 25
# graph for Revenue: total = 14
# graph for company_name_txt: total = 343
# graph for job_state: total = 37
# graph for hq_same_state: total = 2
# graph for python_yn: total = 2
# graph for r_yn: total = 2
# graph for spark_yn: total = 2
# graph for aws_yn: total = 2
# graph for excel_yn: total = 2
# graph for job_simp: total = 7
# graph for seniority: total = 3

# %%
for i in df_cat[['Location', 'Headquarters', 'company_name_txt']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" %(i,len(cat_num)))
    chart = sns.barplot(x = cat_num.index, y = cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation = 90) #for totating labels
    plt.show()
    
#NY has highest job postings followed by CA
#Highest number of headquarters are situated in New York. Chicago being the large city
#The top three companies with more hirings are MassMutual, Takedia Pharma, Reynolds American
# Out:
# graph for Location: total = 20
# graph for Headquarters: total = 20
# graph for company_name_txt: total = 20

# %%
pd.pivot_table(df, index = 'job_simp', values = 'avg_salary')
# Out:
#                            avg_salary
# job_simp
# analyst                     64.621212
# data engineer              105.403361
# data scientist             117.564516
# director                   168.607143
# machine learning engineer  126.431818
# manager                     84.022727
# na                          85.203209

# %%
pd.pivot_table(df, index = ['job_simp', 'seniority'], values = 'avg_salary')
#analysts make less monay then DE and DS
#MLEs make more money than Data Scientists
# Out:
#                                      avg_salary
# job_simp                  seniority
# analyst                   junior      56.500000
#                           na          60.812500
#                           senior      75.480769
# data engineer             na          96.701220
#                           senior     124.689189
# data scientist            junior     106.500000
#                           na         107.043011
#                           senior     138.956522
# director                  na         168.607143
# machine learning engineer na         119.133333
#                           senior     142.071429
# manager                   na          84.022727
# na                        na          73.980620
#                           senior     110.163793

# %%
pd.pivot_table(df, index = 'job_state', values = 'avg_salary').sort_values('avg_salary', ascending = False)
#Interesting to see that NY avg_salary is well behind that of CA (this may be because NY hirings more DA)
# Out:
#            avg_salary
# job_state
# CA         123.513158
# IL         116.662500
# DC         110.181818
# MA         106.281553
# NJ         104.558824
# MI         100.250000
# RI         100.000000
# NY          98.652778
# NC          98.452381
# MD          97.357143
# KY          97.000000
# VA          95.621951
# UT          94.150000
# WA          93.190476
# PA          92.560606
# OR          92.125000
# IN          90.300000
# TX          89.392857
# OH          87.571429
# TN          87.115385
# KS          87.000000
# AZ          85.666667
# MN          85.500000
# MO          84.722222
# GA          80.666667
# IA          78.900000
# FL          77.625000
# CO          77.045455
# NM          74.333333
# WI          73.300000
# CT          71.100000
# SC          60.500000
# AL          57.937500
# ID          56.250000
# LA          52.250000
# NE          41.000000
# DE          27.500000

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
pd.pivot_table(df, index = ['job_state', 'job_simp'], values = 'avg_salary', aggfunc = 'count').sort_values('job_state', ascending = False)
#Illinois has many directors
#CA has more DS, DE compared to NY
# Out:
#                                      avg_salary
# job_state job_simp
# WI        na                                  4
#           data scientist                      3
#           analyst                             3
# WA        na                                  1
#           data scientist                     17
#           analyst                             3
# VA        na                                  5
#           machine learning engineer           2
#           data scientist                     18
#           data engineer                      10
#           analyst                             6
# UT        data engineer                       3
#           analyst                             4
#           data scientist                      3
# TX        na                                  7
#           data scientist                     13
#           data engineer                       8
# TN        data scientist                      1
# ...

# %%
pd.pivot_table(df[df.job_simp == 'data scientist'], index = ['job_state'], values = 'avg_salary').sort_values('avg_salary', ascending = False)
#Data scientists in DC, CA get paid more compared to NY
# Out:
#            avg_salary
# job_state
# DC         149.000000
# CA         142.522059
# UT         140.500000
# MO         127.666667
# IL         117.233333
# NC         117.000000
# NY         115.250000
# MA         113.750000
# WI         113.500000
# PA         113.333333
# MD         109.115385
# CO         108.666667
# VA         108.416667
# NJ         106.875000
# MI         106.625000
# OH         105.285714
# TX         100.730769
# WA          99.764706
# OR          98.500000
# FL          97.357143
# TN          96.000000
# IN          84.500000
# KY          84.000000
# CT          84.000000
# GA          81.333333
# NM          74.333333
# AZ          69.500000

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_name_txt', 'job_state', 'hq_same_state', 'age_of_company',
#        'python_yn', 'r_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'job_simp',
#        'seniority', 'job_desc_len', 'comp_count'],
#       dtype='object')

# %%
#rating, industry, sector, revenue, num of comp, hourly, employer provided, python, r, spark, aws, excel, desc_len, type of ownership

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'comp_count', 'hourly', 'employer_provided', 'python_yn', 'r_yn', 'spark_yn', 'aws_yn', 'excel_yn',  'Type of ownership', 'avg_salary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots, index = i, values = 'avg_salary').sort_values('avg_salary', ascending = False))
    
#it is clear that the companies with rating 5 pay more
#Interestingly 2.5 rated companies do pay well

#Motion Picture Production & Distribution industries pay high salaries

#In sector wise Media pays beter

#We can see that Companies with not the highest revenue pay more

#Hourly workers are paid less

#Most data scientists don't use excel and the data suggests the same, where it is used by data analysts

#Although the count of Private companies is more, Public companies do pay better salaries
# Out:
# Rating
#         avg_salary
# Rating
# -1.0    136.181818
#  5.0    134.700000
#  2.5    120.000000
#  4.5    117.714286
#  4.1    116.368421
#  3.9    113.071429
#  2.6    109.083333
#  4.4    108.606061
#  3.2    105.500000
#  4.0    105.340426
#  3.5    104.897959
#  3.7    104.131148
#  4.7    103.983871
#  4.3    102.468750
#  3.3    101.858974
#  4.2    100.442308
#  2.2     97.750000
#  4.6     97.250000
#  3.8     96.811475
#  2.1     95.900000
#  3.4     93.011364
#  1.9     87.500000
#  3.1     86.580000
#  3.0     85.588235
#  3.6     85.467391
#  2.8     83.928571
#  2.7     83.250000
#  2.3     81.500000
#  2.9     81.138889
#  4.8     80.277778
#  2.4     60.214286
# Industry
#                                           avg_salary
# Industry
# Other Retail Stores                       163.500000
# Motion Picture Production & Distribution  146.000000
# Financial Analytics & Research            145.125000
# Health, Beauty, & Fitness                 139.500000
# ...

# %%
pd.pivot_table(df_pivots, index = 'Revenue', columns = 'python_yn', values = 'avg_salary', aggfunc = 'count')
# Out:
# python_yn                            0      1
# Revenue
# $1 to $2 billion (USD)            16.0   44.0
# $1 to $5 million (USD)             1.0    7.0
# $10 to $25 million (USD)          16.0   16.0
# $10+ billion (USD)                66.0   58.0
# $100 to $500 million (USD)        47.0   44.0
# $2 to $5 billion (USD)            17.0   22.0
# $25 to $50 million (USD)          24.0   16.0
# $5 to $10 billion (USD)            9.0   10.0
# $5 to $10 million (USD)            9.0    9.0
# $50 to $100 million (USD)         21.0   25.0
# $500 million to $1 billion (USD)  29.0   28.0
# -1                                 1.0    NaN
# Less than $1 million (USD)         1.0    3.0
# Unknown / Non-Applicable          93.0  110.0

# %%
#!pip install wordcloud
#!pip install nltk
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
#Mostly used words in job description

# %%
words = " ".join(df["Job Description"])
words[:100]
# Out:
# 'Data Scientist\nLocation: Albuquerque, NM\nEducation Required: Bachelor’s degree required, preferably '

# %%
def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered

words_filtered = punctuation_stop(words)

# %%
text = " ".join([ele for ele in word_filtered])

# %%
text[:100]
# Out:
# 'data scientist location albuquerque nm education required bachelor degree required preferably math e'

# %%
wc = WordCloud(background_color = "white", random_state = 1, stopwords = STOPWORDS, max_words = 2000, width=800 , height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation = "bilinear")
plt.axis('off')
plt.show()
